# %%
from selenium import webdriver  #直接執行 未設定時間
import requests
from bs4 import BeautifulSoup
driver = webdriver.Chrome()
driver.get("https://class.cyut.edu.tw/StdLogin.aspx?m=non&t=%2fselad_01.aspx")
#找到輸入框



#-----------------------------------------------------------------------------
element = driver.find_element_by_name("ctl00$cph_content$txtStuid");
element.send_keys("s10814092");

element1 = driver.find_element_by_name("ctl00$cph_content$txtStdPswd");
element1.send_keys("@Aa7466441");

button = driver.find_element_by_name("ctl00$cph_content$butLogin")
button.click()
#-----------------------------------------------------------------------------
button1 = driver.find_element_by_name("h_seltype");
button1.click()

element2 = driver.find_element_by_name("h_crsno");
element2.send_keys("2461"); # 2461 資料庫   2503 人資管理
#-----------------------------------------------------------------------------
#驗證碼

driver.save_screenshot('test.png')

element3 = driver.find_element_by_id('img_Valid')

element3.location
element3.size

left = element3.location['x']
right = element3.location['x'] + element3.size['width']
top = element3.location['y']
bottom = element3.location['y'] + element3.size['height']

from PIL import Image
img = Image.open('test.png')
img = img.crop((left, top, right, bottom))
img.save('captua.png')


#-----------------------------------------------------------------------------
import ddddocr

ocr = ddddocr.DdddOcr()
with open('captua.png', 'rb') as f:
    img_bytes = f.read()
res = ocr.classification(img_bytes)

#-----------------------------------------------------------------------------
element4 = driver.find_element_by_name("h_verif");
element4.send_keys(res);

#-----------------------------------------------------------------------------
button2 = driver.find_element_by_id("but_submit")
button2.click()

#-----------------------------------------------------------------------------
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder

# %%
import ddddocr

ocr = ddddocr.DdddOcr()
with open('111.bmp', 'rb') as f:
    img_bytes = f.read()
res = ocr.classification(img_bytes)

print(res)
# Out:
# 欢迎使用ddddocr，本项目专注带动行业内卷，个人博客:wenanzhe.com
# 训练数据支持来源于:http://146.56.204.113:19199/preview
# 爬虫框架feapder可快速一键接入，快速开启爬虫之旅：https://github.com/Boris-code/feapder
# 0007

# %%
import time
while True:
    result = time.localtime()
    print(result)
    time.sleep(1)
    if result.tm_hour == 2 and result.tm_min ==28 and result.tm_sec == 30:
        print("good")
        break
# Out:
# time.struct_time(tm_year=2022, tm_mon=2, tm_mday=16, tm_hour=2, tm_min=37, tm_sec=6, tm_wday=2, tm_yday=47, tm_isdst=0)
# time.struct_time(tm_year=2022, tm_mon=2, tm_mday=16, tm_hour=2, tm_min=37, tm_sec=7, tm_wday=2, tm_yday=47, tm_isdst=0)
# time.struct_time(tm_year=2022, tm_mon=2, tm_mday=16, tm_hour=2, tm_min=37, tm_sec=8, tm_wday=2, tm_yday=47, tm_isdst=0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-40b78108a63a> in <module>
#       3     result = time.localtime()
#       4     print(result)
# ----> 5     time.sleep(1)
#       6     if result.tm_hour == 2 and result.tm_min ==28 and result.tm_sec == 30:
#       7         print("good")
#
# KeyboardInterrupt:

# %%
from selenium import webdriver        #設定時間 時間到執行 需輸入一個課號
import requests
from bs4 import BeautifulSoup
driver = webdriver.Chrome()
driver.get("https://class.cyut.edu.tw/StdLogin.aspx?m=non&t=%2fselad_01.aspx")

#-----------------------------------------------------------------------------
val = int(input("Enter your 選課時間(時): "))
val2 = int(input("Enter your 選課時間(分): "))
val3 = int(input("Enter your 選課時間(秒): "))
val4 = input("Enter your 帳號(例:s10814092): ")
val5 = input("Enter your 密碼(例:s10814092): ")
val6 = int(input("Enter your 課號(2461): "))

import time
while True:
    
    result = time.localtime()
    print(result)
    time.sleep(0.5)
    if result.tm_hour == val and result.tm_min ==val2 and result.tm_sec == val3:
        
        element = driver.find_element_by_name("ctl00$cph_content$txtStuid");
        element.send_keys(val4);

        element1 = driver.find_element_by_name("ctl00$cph_content$txtStdPswd");
        element1.send_keys(val5);

        button = driver.find_element_by_name("ctl00$cph_content$butLogin")
        button.click()
        #-----------------------------------------------------------------------------
        button1 = driver.find_element_by_name("h_seltype");
        button1.click()

        element2 = driver.find_element_by_name("h_crsno");
        element2.send_keys(val6); # 2461 資料庫   2503 人資管理
        #-----------------------------------------------------------------------------
        #驗證碼

        driver.save_screenshot('test.png')

        element3 = driver.find_element_by_id('img_Valid')

        element3.location
        element3.size

        left = element3.location['x']
        right = element3.location['x'] + element3.size['width']
        top = element3.location['y']
        bottom = element3.location['y'] + element3.size['height']

        from PIL import Image
        img = Image.open('test.png')
        img = img.crop((left, top, right, bottom))
        img.save('captua.png')


        #-----------------------------------------------------------------------------
        import ddddocr

        ocr = ddddocr.DdddOcr()
        with open('captua.png', 'rb') as f:
            img_bytes = f.read()
        res = ocr.classification(img_bytes)

        #-----------------------------------------------------------------------------
        element4 = driver.find_element_by_name("h_verif");
        element4.send_keys(res);

        #-----------------------------------------------------------------------------
        button2 = driver.find_element_by_id("but_submit")
        button2.click()

        #-----------------------------------------------------------------------------
        break

# %%
from selenium import webdriver        #設定時間 時間到執行 需輸入2個課號
import requests
from bs4 import BeautifulSoup
driver = webdriver.Chrome()
driver.get("https://class.cyut.edu.tw/StdLogin.aspx?m=non&t=%2fselad_01.aspx")

#-----------------------------------------------------------------------------
val = int(input("Enter your 選課時間(時): "))
val2 = int(input("Enter your 選課時間(分): "))
val3 = int(input("Enter your 選課時間(秒): "))
val4 = input("Enter your 帳號(例:s10814092): ")
val5 = input("Enter your 密碼(例:s10814092): ")
val6 = int(input("Enter your 課號1(2461): "))
val7 = int(input("Enter your 課號2(2503): "))
import time
while True:
    
    result = time.localtime()
    print(result.tm_hour ,result.tm_min ,result.tm_sec)
    time.sleep(0.5)
    if result.tm_hour == val and result.tm_min ==val2 and result.tm_sec == val3:
        
        element = driver.find_element_by_name("ctl00$cph_content$txtStuid");
        element.send_keys(val4);

        element1 = driver.find_element_by_name("ctl00$cph_content$txtStdPswd");
        element1.send_keys(val5);

        button = driver.find_element_by_name("ctl00$cph_content$butLogin")
        button.click()
        #-----------------------------------------------------------------------------
        button1 = driver.find_element_by_id("h_seltypeA");
        button1.click()

        element2 = driver.find_element_by_name("h_crsno");
        element2.send_keys(val6); # 2461 資料庫   2503 人資管理
        #-----------------------------------------------------------------------------
        #驗證碼

        driver.save_screenshot('test.png')

        element3 = driver.find_element_by_id('img_Valid')

        element3.location
        element3.size

        left = element3.location['x']
        right = element3.location['x'] + element3.size['width']
        top = element3.location['y']
        bottom = element3.location['y'] + element3.size['height']

        from PIL import Image
        img = Image.open('test.png')
        img = img.crop((left, top, right, bottom))
        img.save('captua.png')


        #-----------------------------------------------------------------------------
        import ddddocr

        ocr = ddddocr.DdddOcr()
        with open('captua.png', 'rb') as f:
            img_bytes = f.read()
        res = ocr.classification(img_bytes)

        #-----------------------------------------------------------------------------
        element4 = driver.find_element_by_name("h_verif");
        element4.send_keys(res);

        #-----------------------------------------------------------------------------
        button2 = driver.find_element_by_id("but_submit")
        button2.click()

        #-----------------------------------------------------------------------------
        #-----------------------------------------------------------------------------
        time.sleep(1)
        #------------------------選下個課號------------------------------------------------
        #-----------------------------------------------------------------------------
        
        button1 = driver.find_element_by_id("h_seltypeA");
        button1.click()

        element2 = driver.find_element_by_name("h_crsno");
        element2.send_keys(val7); # 2461 資料庫   2503 人資管理
        #-----------------------------------------------------------------------------
        #驗證碼

        driver.save_screenshot('test.png')

        element3 = driver.find_element_by_id('img_Valid')

        element3.location
        element3.size

        left = element3.location['x']
        right = element3.location['x'] + element3.size['width']
        top = element3.location['y']
        bottom = element3.location['y'] + element3.size['height']

        from PIL import Image
        img = Image.open('test.png')
        img = img.crop((left, top, right, bottom))
        img.save('captua.png')


        #-----------------------------------------------------------------------------
        import ddddocr

        ocr = ddddocr.DdddOcr()
        with open('captua.png', 'rb') as f:
            img_bytes = f.read()
        res = ocr.classification(img_bytes)

        #-----------------------------------------------------------------------------
        element4 = driver.find_element_by_name("h_verif");
        element4.send_keys(res);

        #-----------------------------------------------------------------------------
        button2 = driver.find_element_by_id("but_submit")
        button2.click()
        
        print("完成")
        break
